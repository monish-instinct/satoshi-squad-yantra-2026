# %%
import pandas as pd

df = pd.read_csv("C:/Users\Admin\Downloads\LSTM_demo.csv")
df.head()
# Out:
#                                      id       batch_id  \
# 0  0659881a-d6a7-49ad-832a-58fc6d2819ff  DEMO-IBUP-002
# 1  18dcf2cd-a256-4b81-910d-2ef0817808f0  DEMO-AMOX-001
# 2  1e4e39b8-db4e-4b3c-aec3-7255b8376d68  DEMO-PARA-003
# 3  2097edd2-3055-4e7c-96e5-856b065b8169  DEMO-PARA-003
# 4  258b544e-c4eb-4e12-8b9d-3f1cdd7452cc  DEMO-IBUP-002
#
#                         scanner_user_id verification_status   latitude  \
# 0  b78daa61-0978-4452-b3c7-db78f76cf432          suspicious  40.735074
# 1  b78daa61-0978-4452-b3c7-db78f76cf432           authentic -23.564599
# 2  78dcaf0e-b394-4f1e-a9e3-2a3b97e225a8           authentic  34.054413
# 3  b78daa61-0978-4452-b3c7-db78f76cf432           authentic  28.606078
# 4  b78daa61-0978-4452-b3c7-db78f76cf432           authentic  35.666845
#
#     longitude                                      anomaly_flags  \
# 0  -73.973076  ["Rapid scanning detected","Geographic anomaly...
# 1  -46.585125                                                 []
# ...
